# %%
exports32 = '''0007E110     1  AcquireDDThreadLock
  00009B60     2  AltSetTexture7Hook@12
  0008C810     3  AppendDump@4
  00019100     4  ApplyStateBlock9Hook@4
  00061B50     5  ChangeGl24BitTextureIndianes
  0001BDC0     6  Clear9Hook@28
  00062B00     7  Clr2clr
  0001BCB0     8  ColorFill9Hook@16
  0007E160     9  CompleteCreateSysmemSurface
  000137A0    10  CopyRects8Check
  00015F70    11  CreateCubeTexture9Hook@32
  00016660    12  CreateDepthStencilSurface9Hook@36
  00075F50    13  CreateFileA_Hook@28
  00075F00    14  CreateFileW_Hook@28
  00018E70    15  CreateIndexBuffer9Hook@28
  0002A2E0    16  CreatePixelShader10Hook@16
  00039CD0    17  CreatePixelShader11Hook@20
  00012080    18  CreatePixelShader8Hook@12
  0001C8C0    19  CreatePixelShader9Hook@12
  0008A510    20  CreateProcessAHook@40
  0008A520    21  CreateProcessWHook@40
  000162C0    22  CreateRenderTarget9Hook@36
  00003BF0    23  CreateSurfaceHook
  00012330    24  CreateTexture8Hook@32
  0001D080    25  CreateTexture9Hook@36
  00016A10    26  CreateTx9HD@36
  0000FD30    27  CreateVertexBuffer8Hook@24
  00018E80    28  CreateVertexBuffer9Hook@28
  000843F0    29  Critical
  0002C8C0    30  D3D10ClearDepthStencilViewHook@20
  0002C0E0    31  D3D10ClearRenderTargetViewHook@12
  00028D00    32  D3D10CopyResourceHook@12
  00029220    33  D3D10CopySubresourceRegionHook@36
  00036E20    34  D3D10CreateDeviceHook@24
  00028180    35  D3D10CreateShaderResourceViewHook@16
  0002FA90    36  D3D10CreateShaders
  0002F480    37  D3D10CreateSysTexture
  0002F520    38  D3D10CreateTexture2D
  00028810    39  D3D10CreateTexture2DHook@16
  000321D0    40  D3D10DeviceFromChain
  0002D590    41  D3D10DvcFromSChain
  0002E7C0    42  D3D10GetTexture2D
  000310D0    43  D3D10LoadTexture
  00029500    44  D3D10MapHook@20
  0002A9D0    45  D3D10OMGetRenderTargetsHook@16
  0002B030    46  D3D10OMSetRenderTargetsHook@16
  000274F0    47  D3D10PSSetSamplersHook@16
  00027510    48  D3D10PSSetShaderResourcesHook@16
  0002A910    49  D3D10PsSetShaderHook@8
  000289A0    50  D3D10ResolveSubresourceHook@24
  00028190    51  D3D10ResourceViewReleaseHook@4
  00028100    52  D3D10Texture2DReleaseHook@4
  00029620    53  D3D10UnmapHook@8
  000293B0    54  D3D10UpdateSubresourceHook@28
  0003A6C0    55  D3D11ClearDepthStencilViewHook@20
  0003A5C0    56  D3D11ClearRenderTargetViewHook@12
  00037620    57  D3D11CopyResourceHook@12
  00037700    58  D3D11CopySubresourceRegionHook@36
  00036D80    59  D3D11CreateDeviceHook@40
  00035270    60  D3D11CreateSamplerHook@12
  00037F30    61  D3D11CreateShaderResourceViewHook@16
  00042AF0    62  D3D11CreateShaders
  0003B740    63  D3D11CreateSwapChain@16
  0003B400    64  D3D11CreateSwapChainForHwnd@28
  000427A0    65  D3D11CreateTexture2D
  00037160    66  D3D11CreateTexture2DHook@16
  0003A400    67  D3D11DiscardViewHook@8
  0004BA60    68  D3D11FixDXBCShaderTest@16
  00043910    69  D3D11GetDeviceOutput@4
  000402E0    70  D3D11GetTexture2D
  0003B2A0    71  D3D11HDSetUP
  00039A90    72  D3D11InsetPxDump
  00042F40    73  D3D11LoadTexture
  00037B60    74  D3D11MapHook@24
  0003A240    75  D3D11OMGetRenderTargetsHook@16
  0003A3C0    76  D3D11OMSetRenderTargetsHook@16
  00036E80    77  D3D11PSSetSamplersHook@16
  00037FB0    78  D3D11PSSetShaderResourcesHook@16
  0003A150    79  D3D11PsSetShaderHook@16
  00043790    80  D3D11Resize
  0003B940    81  D3D11ResizeBuffersHook@24
  0003C050    82  D3D11ResizeTargetHook@8
  00037500    83  D3D11ResolveSubresourceHook@24
  00037F40    84  D3D11ResourceViewReleaseHook@4
  0003B330    85  D3D11SetUPSwapChain1
  00036E30    86  D3D11SetupFinished@4
  00037E40    87  D3D11Texture2DReleaseHook@4
  00037D40    88  D3D11UnmapHook@12
  00037390    89  D3D11UpdateSubresourceHook@28
  00052340    90  D3D12Config64@8
  00051E90    91  D3D12Config@8
  0004C3C0    92  D3D12DXGISwapChainGetDesc1Hook@8
  0004C350    93  D3D12DXGISwapChainGetDescHook@8
  0004C5C0    94  D3D12GetClientRectHook@8
  000583F0    95  D3D12GetDisplayModeListHook@20
  00054AE0    96  D3D12GetSwapChainOutput@4
  000524B0    97  D3D12IsWindowFullscreen
  00061570    98  D3D12ResizeGameWindow@4
  0000FAA0    99  D3D8FreeReplacement
  0000F980   100  D3D8GetBasetexture
  0000FA40   101  D3D8GetReplacement
  0000F9E0   102  D3D8GetSDTexture@4
  00012030   103  D3D8GetmaxPrimitiveCount
  0000FB30   104  D3D8HDSetUP
  0000F420   105  D3D8ReplaceRTTexture@8
  0000F160   106  D3D8Replacetexture@8
  0001C610   107  D3D9GetMonitorInfoAHook@8
  0001C5A0   108  D3D9GetSystemMetricsHook@4
  00014760   109  D3D9HDSetUP
  000228D0   110  D3D9_DrawRect
  00014790   111  D3D9_EndSceneHook@4
  0007E1B0   112  D3DParseUnknownCommand
  000FF6D0   113  DD3D1DeviceLayerTest@0
  0000C560   114  DDCPUDeinterlace@4
  000028B0   115  DDFromSurface@4
  00002D40   116  DDFromTexture@4
  0007E200   117  DDGetAttachedSurfaceLcl
  0007E250   118  DDInternalLock
  0007E2A0   119  DDInternalUnlock
  0000C980   120  DDMaskSurface@8
  00081030   121  DDSToBGRA@20
  00004800   122  DDSurfaceAttachData
  0000D8F0   123  DDrawBrowseTextures@4
  00001B90   124  DDrawDisplayModeChanged
  000D0C30   125  DDrawLayerTest@0
  000FFD70   126  DDrawsSurfaceLayerTest@0
  0000D0F0   127  DDxBRzScale@12
  00066110   128  DIEnumEffectsA
  00066490   129  DIEnumEffectsW
  0006BD30   130  DIGetRange
  000B3B80   131  DSndCreate8Hook@12
  000B3380   132  DSndCreateHook@12
  0007E2F0   133  DSoundHelp
  0003A810   134  DXGIGetBufferHook@16
  00012210   135  DeletePixelShader8Hook@8
  0006B2C0   136  Di8GetDvcCaps@8
  0006A0C0   137  Di8GetDvcCapsW@8
  0006BB70   138  DiDcvSetDataFormat@8
  0006E7B0   139  DiEnumObjects8Hook@16
  0006BB00   140  DiEnumObjects8WHook@16
  0006E740   141  DiEnumObjectsHook@16
  0006BA90   142  DiEnumObjectsWHook@16
  00069D60   143  DiGetDvcCaps@8
  00069F10   144  DiGetDvcCapsW@8
  00065B90   145  DiGetEffectInfoA@12
  00065E40   146  DiGetEffectInfoW@12
  0006ABB0   147  DinputCreateEffectHook@20
  0006CFB0   148  DinputDevice8GetState@12
  0006CF40   149  DinputDevice8GetStateW@12
  00069BE0   150  DinputDevice8SetProperty@12
  000677D0   151  DinputDevice8SetPropertyW@12
  0006E820   152  DinputDeviceGetData@20
  0006CED0   153  DinputDeviceGetState@12
  0006D020   154  DinputDeviceGetStateW@12
  000674F0   155  DinputDeviceSetProperty@12
  00067660   156  DinputDeviceSetPropertyW@12
  00068120   157  DinputEnumEffectsHook@12
  0006CB80   158  DinputSetStates@12
  0007E340   159  DirectDrawCreateClipper
  0007E390   160  DirectDrawCreateEx
  0007E3E0   161  DirectDrawEnumerateA
  0007E480   162  DirectDrawEnumerateExA
  0007E4D0   163  DirectDrawEnumerateExW
  0007E430   164  DirectDrawEnumerateW
  0007E070   165  DirectInputCreateA
  0007E0C0   166  DirectInputCreateW
  000775B0   167  DisableFontAA
  000877B0   168  DisableHook
  0007DFD0   169  DllRegisterServer
  0007E020   170  DllUnregisterServer
  0007DF30   171  Dll_CanUnloadNow
  0007DF80   172  Dll_GetClassObject
  00006240   173  DrawIndexedPrimitive2Hook@32
  00006500   174  DrawIndexedPrimitive3Hook@32
  00006A30   175  DrawIndexedPrimitive3VBHook@24
  00008FD0   176  DrawIndexedPrimitive7VBHook@32
  00010430   177  DrawIndexedPrimitive8Hook@24
  00019BA0   178  DrawIndexedPrimitive9Hook@28
  00010420   179  DrawIndexedPrimitiveUP8Hook@36
  00019880   180  DrawIndexedPrimitiveUP9Hook@36
  00005F00   181  DrawPrimitive2Hook@24
  000063A0   182  DrawPrimitive3Hook@24
  00006640   183  DrawPrimitive3VBHook@24
  00008D20   184  DrawPrimitive7Hook@24
  00008E40   185  DrawPrimitive7VBHook@24
  00013C70   186  DrawPrimitive8Hook@16
  0001AB70   187  DrawPrimitive9Hook@16
  00013B00   188  DrawPrimitiveUp8Hook@20
  0001AFD0   189  DrawPrimitiveUp9Hook@20
  000622C0   190  DumpDDS
  00019050   191  EndStateBlock9Hook@8
  000715C0   192  FileHooksInsertFile@8
  00061980   193  FindDXTnTextureInCollection
  00084D50   194  FindProcAddressInIat
  000617E0   195  FindTextureInCollection
  00002060   196  FlipHook@12
  000775D0   197  GDISetHz
  00004200   198  GetAttachedSurface4Hook@12
  00003F00   199  GetAttachedSurfaceHook@12
  0001BBF0   200  GetBackBuffer9Hook@20
  0000FB60   201  GetContainer8
  0000FBB0   202  GetContainer8S
  000296A0   203  GetD3D10Device
  00038530   204  GetD3D11DvcFromDXGIDvc
  00061F10   205  GetDDSFileFormat
  00007990   206  GetDDSurface7Replacement
  00004500   207  GetDDSurfaceLevel
  0007E520   208  GetDDSurfaceLocal
  0001BB70   209  GetDepthStencilSurface9Hook@8
  0001BC30   210  GetDesc9Hook@8
  00026ED0   211  GetDirect3D10
  000272B0   212  GetDirect3D10_1
  00036600   213  GetDirect3D11
  0000FC50   214  GetFaceAndLevel8
  00091290   215  GetGlPixelFormat@16
  00084A20   216  GetLayerObjectsCount@0
  0007E570   217  GetOLEThunkData
  0001BAF0   218  GetRenderTarget9Hook@12
  0001C080   219  GetRenderTargetData9Hook@12
  0001B3C0   220  GetScissorRect9Hook@8
  00004D20   221  GetSurface4ID
  0007E5C0   222  GetSurfaceFromDC
  000055A0   223  GetSurfaceID
  00012F30   224  GetSurfaceLevel8Hook@12
  0001D8D0   225  GetSurfaceLevel9Hook@12
  00059580   226  GetSwapChainWindowHandle
  00004DA0   227  GetTexture2ID
  00004E00   228  GetTextureID
  0001B120   229  GetViewPort9Hook@8
  00093430   230  GlCompileShaders
  0008FA10   231  GlDisplayModeChanged
  00090A60   232  GlDrawRect
  00090F40   233  GlLock@0
  00090F70   234  GlUnlock@0
  00090260   235  GlWriteOnTexture
  00084DA0   236  HookIatFunction
  00084550   237  HookQueryPerformanceCounter
  00039970   238  IDXGISwapChainPresentHook@12
  00006C50   239  IDirect3DDevice3_Clear
  00007890   240  IDirect3DDevice3_DrawRect@12
  00006EE0   241  IDirect3DDevice3_DrawRectWithFlags@16
  00009AA0   242  IDirect3DDevice7_DrawRect@12
  00009160   243  IDirect3DDevice7_DrawRectWithFlags
  00005B80   244  IDirect3DDevice_ExecuteHook@16
  00003EB0   245  IDirectDrawGetCapsHook
  000B6A40   246  InitClientSocket
  0008A4F0   247  InitCreateProcessHook
  0003ED50   248  InitD3D11Hooks@20
  0000FAC0   249  InitD3D8HooksData
  00001BC0   250  InitD3DHooksData
  00067080   251  InitDInputHooks@4
  00159940   252  InitDInputLayer@0
  000B6980   253  InitDSoundHooks
  00071680   254  InitFileHooks
  0008FA40   255  InitGl
  0008F940   256  InitGlHooks
  00014110   257  InitHDHooks9
  00088540   258  InitMouseHooks
  000B6AC0   259  InitTowHooks@0
  00081BD0   260  InitWinMMHooks@8
  000CDBB0   261  InitWineHoooks@4
  00038580   262  IsD3D11Device
  0008B360   263  IsDump
  00086AA0   264  IsXInputDevice
  00161160   265  LayerDsoundTest
  000B10C0   266  Line2Rect
  00061CC0   267  LoadData2Surface
  0008DE70   268  LoadDumps@8
  00005060   269  Lock4Hook@20
  00005790   270  LockHook@20
  00013270   271  LockManagedSurface8RectHook@16
  0001DB70   272  LockManagedSurface9RectHook@16
  000132E0   273  LockSurface8RectHook@16
  000020D0   274  LockSurfaceHook@20
  00012640   275  LockTexture8RectHook@20
  000126E0   276  LockTexture8RectHookCheck@20
  0001D560   277  LockTexture9RectHook@20
  00003670   278  LogDDSrfacePxFormat
  00081CB0   279  MCINofify@4
  00002580   280  ManagerLock4@20
  00002610   281  ManagerUnLock4@8
  000361E0   282  OMSetRenderTargetsAndUnorderedAccessViewsHook@32
  00013070   283  OldReleaseSurface8Hook@4
  00087780   284  PointerCollectionCreate
  00015250   285  Present9Hook@20
  000175D0   286  ProcessVertices9Hook@28
  0007DDB0   287  ProxyResume@0
  0007E610   288  RegisterSpecialCase
  00087860   289  ReleaseAllHooks
  0001E120   290  ReleaseCubeSurface9Hook@4
  0001D8E0   291  ReleaseCubeTexture9Hook@4
  0007E660   292  ReleaseDDThreadLock
  0002A800   293  ReleasePixelShader10Hook@4
  0003A040   294  ReleasePixelShader11Hook@4
  0001CC20   295  ReleasePixelShader9Hook@4
  0001DB10   296  ReleaseRTSurface9Hook@4
  00019180   297  ReleaseStateBlock9Hook@4
  000130B0   298  ReleaseSurface8Hook@4
  0001D940   299  ReleaseSurface9Hook@4
  00012590   300  ReleaseTexture8Hook@4
  0001D4C0   301  ReleaseTexture9Hook@4
  00084A30   302  RunScript
  00073990   303  SHGetKnownFolder_Hook@16
  00080FD0   304  SaveDDS@32
  000B0AB0   305  Scale
  000B0E70   306  ScaleX
  000B0850   307  Scaler
  00078010   308  SendKey
  000BB0E0   309  Serve@4
  0007E6B0   310  SetAppCompatData
  000079C0   311  SetDDSurface7Replacement
  000038F0   312  SetDDSurfacePixelFormat
  0001BAB0   313  SetDepthStencilSurface9Hook@8
  00018EA0   314  SetFVF9Hook@8
  0008A3D0   315  SetMouseHooksParams
  0008FC90   316  SetPixelFormatHook@12
  00012280   317  SetPixelShader8Hook@8
  0001CE00   318  SetPixelShader9Hook@8
  0001CD10   319  SetPixelShader9HookD@8
  00083430   320  SetProcAffinity@8
  00006330   321  SetRenderState2Hook@12
  0001B700   322  SetRenderTarget9Hook@12
  0008B270   323  SetSampleCount@4
  0001CEC0   324  SetSamplerState9Hook@16
  0001B420   325  SetScissorRect9Hook@8
  000103C0   326  SetStreamSource8Hook@16
  00018FA0   327  SetStreamSource9Hook@20
  000078C0   328  SetTexture3Hook@12
  00009AD0   329  SetTexture7Hook@12
  00012490   330  SetTexture8Hook@12
  0001D300   331  SetTexture9Hook@12
  0008B280   332  SetTexturePaths@8
  00083D40   333  SetThreadAffinity@4
  00018F10   334  SetVertexDeclaration9Hook@8
  00010350   335  SetVertexShader8Hook@8
  00018F60   336  SetVertexShader9Hook@8
  0001B1F0   337  SetViewPort9Hook@8
  00084420   338  SetWin9xFlag
  00084420   339  SetWin9xFlag@4
  00002710   340  SrfcQueryHook@12
  0001B560   341  StretchRect9Hook@24
  000023E0   342  SurfaceBltFastHook@24
  000022D0   343  SurfaceBltHook@24
  00002490   344  SurfaceGetDCHook@8
  000024F0   345  SurfaceReleaseDCHook@8
  00084510   346  TimeGetTimeF@0
  00084430   347  TimeGetTimeHook@0
  00084490   348  TimeGetTimeHookZero@0
  000B7400   349  TowDecrypt
  000B72D0   350  TowEncrypt
  000B7310   351  TowLegDecrypt
  000B7A20   352  TowPacket
  00006BB0   353  TransformVertices3Hook@20
  00009BF0   354  TsExecute@16
  00005230   355  UnLock4Hook@8
  000058A0   356  UnLockHook@8
  0001DD50   357  UnLockManagedSurface9RectHook@4
  00002270   358  UnLockSurface4Hook@8
  00013350   359  UnLockSurface8RectHook@4
  00002210   360  UnLockSurfaceHook@8
  00012790   361  UnLockTexture8RectHook@8
  0001D620   362  UnLockTexture9RectHook@8
  0001BFD0   363  UpdateHDSurface9Hook@20
  0001E080   364  UpdateSurface9Hook@20
  00012C00   365  UpdateTexture8Hook@12
  0001D3D0   366  UpdateTexture9Hook@12
  0000FD90   367  Vb8LockHook@20
  000102D0   368  Vb8UnLockHook@4
  00078540   369  VlcDDrawPlay@12
  0007AFA0   370  VlcPlay@4
  000D0290   371  WrappDDraw7Object@4
  000D0240   372  WrappDDrawObject@4
  00011AB0   373  _D3D8DrawRect
  00011AF0   374  _D3D8Write
  00004E60   375  _Lock4Hook@20
  00005600   376  _LockHook@20
  000B0EF0   377  _Scale
  0007DDD0   378  _Z16DirectDrawCreatev
  0007DE80   379  _Z19DirectInputCreateExv
  00075870   380  __CreateFileW_Hook@32
  00011400   381  __D3D8DrawRect
  00061D50   382  copyData2Surface
  00091070   383  glBindFramebuffer_Hook@8
  00091160   384  glBindTexture_Hook@8
  000910D0   385  glBlitFramebuffer_Hook
  00092B20   386  glCompressedTexImage2D_Hook@32
  00093340   387  glDeleteRenderbuffers_Hook@8
  00093150   388  glGetIntegerv_Hook@8
  00093260   389  glRenderbufferStorageMultisample_Hook@20
  00093190   390  glRenderbufferStorage_Hook@16
  00093110   391  glSamplerParameteri_Hook@12
  00091000   392  glScissor_Hook@16
  000933A0   393  glTexImage2DMultisample_Hook@24
  00092360   394  glTexImage2D_Hook@36
  000930D0   395  glTexParameteri_Hook@12
  00091750   396  glTexSubImage2D_Hook@36
  00090F90   397  glViewport_Hook@16
  00081260   398  mixerGetControlDetailsAHook@12
  00081150   399  mixerGetLineControlsAHook@12
  000810F0   400  mixerGetLineInfoAHook@12
  000811D0   401  mixerSetControlDetailsAHook@12
  000877D0   402  sethook
  00086970   403  sigscan
  00061DA0   404  surfaceCopy
  00087820   405  unhook
  0001C680   406  vPosReset9
  000153E0   407  xBRPresent9Hook@20
  00080F50   408  xBRzCreate@4
  00080F10   409  xBRzUPscale@20
  00080EF0   410  xBRzfree@4'''

# %%
exp32 = [line.split(' ')[-1] for line in exports32.split('\n')]
exp32 = ''.join([expt.split('@')[0] + '=' + expt + '\n' for expt in exp32 if expt.find('@')>-1])
print(exp32)
# Out:
# AltSetTexture7Hook=AltSetTexture7Hook@12
# AppendDump=AppendDump@4
# ApplyStateBlock9Hook=ApplyStateBlock9Hook@4
# Clear9Hook=Clear9Hook@28
# ColorFill9Hook=ColorFill9Hook@16
# CreateCubeTexture9Hook=CreateCubeTexture9Hook@32
# CreateDepthStencilSurface9Hook=CreateDepthStencilSurface9Hook@36
# CreateFileA_Hook=CreateFileA_Hook@28
# CreateFileW_Hook=CreateFileW_Hook@28
# CreateIndexBuffer9Hook=CreateIndexBuffer9Hook@28
# CreatePixelShader10Hook=CreatePixelShader10Hook@16
# CreatePixelShader11Hook=CreatePixelShader11Hook@20
# CreatePixelShader8Hook=CreatePixelShader8Hook@12
# CreatePixelShader9Hook=CreatePixelShader9Hook@12
# CreateProcessAHook=CreateProcessAHook@40
# CreateProcessWHook=CreateProcessWHook@40
# CreateRenderTarget9Hook=CreateRenderTarget9Hook@36
# CreateTexture8Hook=CreateTexture8Hook@32
# CreateTexture9Hook=CreateTexture9Hook@36
# CreateTx9HD=CreateTx9HD@36
# CreateVertexBuffer8Hook=CreateVertexBuffer8Hook@24
# CreateVertexBuffer9Hook=CreateVertexBuffer9Hook@28
# ...
